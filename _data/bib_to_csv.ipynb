# %%
import csv
import re

def parse_bibtex(bibtex_file):
    references = []
    with open(bibtex_file, 'r') as file:
        data = file.read()
        data = data.replace('\\\'{e}', 'é')
        entries = re.findall(r'@(\w+)\{(.*?),\s*([^@]*)\}', data, re.DOTALL)
        for entry in entries:
            entry_type = entry[0].strip()
            entry_key = entry[1].strip()
            entry_data = entry[2].strip()
            reference = {'entry_type': entry_type}
            fields = re.findall(r'(\w+)\s*=\s*(\{(?:[^{}]|[^{}]*\{[^{}]*\}[^{}]*)*\}|"[^"]*"|\S+)', entry_data)
            for field in fields:
                key, value = field
                reference[key] = value.strip('{}"')
            references.append(reference)
    return references

def write_csv(references, csv_file):
    fieldnames = ['entry_type', 'author', 'title', 'journal', 'fjournal', 'year', 'volume', 'pages', 'eprint', 'url', 'eprinturl', 'publisher', 'address']
    with open(csv_file, 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        for reference in references:
            writer.writerow({field: reference.get(field, '') for field in fieldnames})


# Example usage
bibtex_file = 'publication.bib'
csv_file = 'publication.csv'

references = parse_bibtex(bibtex_file)
write_csv(references, csv_file)

# %%
import pandas as pd
df = pd.read_csv('publication.csv', dtype=str)
def rename(s):
    authors = s.split(' and ')
    authors = [' '.join(author.split(', ')[::-1]) for author in authors]
    return ', '.join(authors)

df['author'] = df.author.apply(rename)
df['title'] = df.title.apply(lambda s: s.replace('{', '').replace('}', ''))
df['volume'] = df.volume.astype('Int64')

df.to_csv('publication.csv')

# %%
df
# Out:
#         entry_type                                             author  \
# 0          article                Luhao Zhang, Jincheng Yang, Rui Gao
# 1          article                   Alexis F. Vasseur, Jincheng Yang
# 2          article                                      Jincheng Yang
# 3          article                   Alexis F. Vasseur, Jincheng Yang
# 4          article  Jincheng Yang, Luhao Zhang, Ningyuan Chen, Rui...
# 5          article                Luhao Zhang, Jincheng Yang, Rui Gao
# 6          article                                      Jincheng Yang
# 7          article                   Alexis F. Vasseur, Jincheng Yang
# 8          article                  Zhiwu Lin, Jincheng Yang, Hao Zhu
# 9          article                           Jincheng Yang, Zhiwu Lin
# 10       phdthesis                                      Jincheng Yang
# 11  bachelorthesis                                      Jincheng Yang
# 12            book            Tao Xie, Xiangqian Cheng, Jincheng Yang
#
#                                                 title  \
# 0   Optimal robust policy for feature-based newsve...
# 1   Layer separation of the 3D incompressible Navi...
# 2   Vorticity interior trace estimates and higher ...
# 3   Boundary vorticity estimates for Navier--Stoke...
# 4   Decision-making with side information: a causa...
# 5   A simple and general duality proof for Wassers...
# 6   Construction of maximal functions associated w...
# 7   Second derivatives estimate of suitable soluti...
# 8               Barotropic instability of shear flows
# 9   Linear inviscid damping for Couette flow in st...
# 10  Partial regularity results for the three-dimen...
# 11  Linear inviscid damping of a shear Flow in a h...
# 12                   RAPTOR Programme Design Tutorial
#
#                                         journal  \
# 0                            Management Science
# 1                      Comm. Part. Diff. Equat.
# 2                                arXiv e-prints
# 3                            SIAM J. Math Anal.
# 4                            OptOnline e-prints
# 5                                arXiv e-prints
# 6   Ann. Inst. H. Poincaré C Anal. Non Linéaire
# 7                     Arch. Ration. Mech. Anal.
# 8                             Stud. Appl. Math.
# 9       Journal of Mathematical Fluid Mechanics
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
#
#                                              fjournal  year  volume  \
# 0                                  Management Science  2024      70
# 1    Communications in Partial Differential Equations  2024    <NA>
# 2                                                 NaN  2023    <NA>
# 3               SIAM Journal on Mathematical Analysis  2023      55
# 4                                                 NaN  2022    <NA>
# 5                                                 NaN  2022    <NA>
# 6   Annales de l'Institut Henri Poincaré C. Analys...  2022      39
# 7         Archive for Rational Mechanics and Analysis  2021     241
# 8                      Studies in Applied Mathematics  2020     144
# 9             Journal of Mathematical Fluid Mechanics  2018      20
# 10                                                NaN  2022    <NA>
# 11                                                NaN  2017    <NA>
# 12                                                NaN  2014    <NA>
#
#                pages      eprint  \
# 0          2315-2329       18579
# 1                NaN  2303.05236
# 2   arXiv:2308.09350  2308.09350
# 3         3081--3107  2110.02426
# 4                NaN       20639
# 5   arXiv:2205.00362  2205.00362
# 6           793--818  2008.05588
# 7           683--727  2009.14291
# 8           289--326  1801.00950
# 9           445--472  1610.08924
# 10               NaN         NaN
# 11               NaN         NaN
# 12               NaN         NaN
#
#                                                   url  \
# 0              https://doi.org/10.1287/mnsc.2023.4810
# 1       https://doi.org/10.1080/03605302.2024.2346146
# 2                https://arxiv.org/pdf/2308.09350.pdf
# 3                https://doi.org/10.1137%2F22m1503567
# 4                                                 NaN
# 5                                                 NaN
# 6                    https://doi.org/10.4171/aihpc/20
# 7          https://doi.org/10.1007/s00205-021-01661-4
# 8                  https://doi.org/10.1111/sapm.12297
# 9           https://doi.org/10.1007/s00021-017-0328-3
# 10                                                NaN
# 11                                                NaN
# 12  http://www.tup.tsinghua.edu.cn/booksCenter/boo...
#
#                                             eprinturl  \
# 0   https://optimization-online.org/wp-content/upl...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   https://optimization-online.org/wp-content/upl...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#                                             publisher       address
# 0                                                 NaN           NaN
# 1                                   Taylor \& Francis           NaN
# 2                                                 NaN           NaN
# 3   Society for Industrial {\&} Applied Mathematic...           NaN
# 4                                                 NaN           NaN
# 5                                                 NaN           NaN
# 6                                                 NaN           NaN
# 7                                                 NaN           NaN
# 8                                                 NaN           NaN
# 9                                                 NaN           NaN
# 10                                                NaN   Austin, USA
# 11                                                NaN  Xi'an, China
# 12                          Tsinghua University Press       Beijing
