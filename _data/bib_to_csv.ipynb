# %%
import csv
import re

def parse_bibtex(bibtex_file):
    references = []
    with open(bibtex_file, 'r') as file:
        data = file.read()
        data = data.replace('\\\'{e}', 'é')
        entries = re.findall(r'@(\w+)\{(.*?),\s*([^@]*)\}', data, re.DOTALL)
        for entry in entries:
            entry_type = entry[0].strip()
            entry_key = entry[1].strip()
            entry_data = entry[2].strip()
            reference = {'entry_type': entry_type}
            fields = re.findall(r'(\w+)\s*=\s*(\{(?:[^{}]|[^{}]*\{[^{}]*\}[^{}]*)*\}|"[^"]*"|\S+)', entry_data)
            for field in fields:
                key, value = field
                reference[key] = value.strip('{}"')
            references.append(reference)
    return references

def write_csv(references, csv_file):
    fieldnames = ['entry_type', 'author', 'title', 'journal', 'sjournal', 'year', 'volume', 'pages', 'eprint', 'url', 'eprinturl', 'publisher', 'address', 'link', 'optonline']
    with open(csv_file, 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        for reference in references:
            writer.writerow({field: reference.get(field, '') for field in fieldnames})


# Example usage
bibtex_file = 'publication.bib'
csv_file = 'publication.csv'

references = parse_bibtex(bibtex_file)
write_csv(references, csv_file)

# %%
import pandas as pd
df = pd.read_csv('publication.csv', dtype=str)
def rename(s):
    authors = s.split(' and ')
    authors = [' '.join(author.split(', ')[::-1]) for author in authors]
    return ', '.join(authors)

df['author'] = df.author.apply(rename)
df['title'] = df.title.apply(lambda s: s.replace('{', '').replace('}', ''))
df['volume'] = df.volume.astype('Int64')

df.to_csv('publication.csv')

# %%
df
# Out:
#         entry_type                                             author  \
# 0          article  Jacob Bedrossian, Jiajie Chen, Maria Pia Guald...
# 1          article                 Matei P. Coiculescu, Jincheng Yang
# 2          article  Jincheng Yang, Vincent R. Martinez, Anna L. Ma...
# 3          article                             Fei Cao, Jincheng Yang
# 4          article                                      Jincheng Yang
# 5          article                Luhao Zhang, Jincheng Yang, Rui Gao
# 6          article                   Alexis F. Vasseur, Jincheng Yang
# 7          article                Luhao Zhang, Jincheng Yang, Rui Gao
# 8          article                   Alexis F. Vasseur, Jincheng Yang
# 9          article  Jincheng Yang, Luhao Zhang, Ningyuan Chen, Rui...
# 10         article                                      Jincheng Yang
# 11         article                   Alexis F. Vasseur, Jincheng Yang
# 12         article                  Zhiwu Lin, Jincheng Yang, Hao Zhu
# 13         article                           Jincheng Yang, Zhiwu Lin
# 14       phdthesis                                      Jincheng Yang
# 15  bachelorthesis                                      Jincheng Yang
# 16            book            Tao Xie, Xiangqian Cheng, Jincheng Yang
#
#                                                 title  \
# 0   Finite time singularities in the Landau equati...
# 1   Conditional Liouville theorems for the Navier-...
# 2   Energy dissipation near the outflow boundary i...
# 3   Quantitative convergence guarantees for the me...
# 4   Vorticity interior trace estimates and higher ...
# 5   A Short and General Duality Proof for Wasserst...
# 6   Layer separation of the 3D incompressible Navi...
# 7   Optimal robust policy for feature-based newsve...
# 8   Boundary vorticity estimates for Navier--Stoke...
# 9   Decision-making with side information: a causa...
# 10  Construction of maximal functions associated w...
# 11  Second derivatives estimate of suitable soluti...
# 12              Barotropic instability of shear flows
# 13  Linear inviscid damping for Couette flow in st...
# 14  Partial regularity results for the three-dimen...
# 15  Linear inviscid damping of a shear flow in a h...
# 16                   RAPTOR programme design tutorial
#
#                                               journal  \
# 0               submitted to Inventiones Mathematicae
# 1   Calculus of Variations and Partial Differentia...
# 2              Indiana University Mathematics Journal
# 3           Discrete and Continuous Dynamical Systems
# 4                   Journal of Differential Equations
# 5                                 Operations Research
# 6    Communications in Partial Differential Equations
# 7                                  Management Science
# 8               SIAM Journal on Mathematical Analysis
# 9               Minor revision at Operations Research
# 10  Annales de l'Institut Henri Poincaré C. Analys...
# 11        Archive for Rational Mechanics and Analysis
# 12                     Studies in Applied Mathematics
# 13            Journal of Mathematical Fluid Mechanics
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
#
#                                        sjournal  year  volume       pages  \
# 0                                           NaN  2026    <NA>         NaN
# 1                                           NaN  2026      65          22
# 2                        Indiana Univ. Math. J.  2025    <NA>         NaN
# 3                   Discrete Contin. Dyn. Syst.  2026      47     487-518
# 4                               J. Differ. Equ.  2025     442      113486
# 5                                    Oper. Res.  2025      73   2146-2155
# 6          Comm. Partial Differential Equations  2024      49    381--409
# 7                                   Manag. Sci.  2024      70   2315-2329
# 8                            SIAM J. Math Anal.  2023      55  3081--3107
# 9                                           NaN  2022    <NA>         NaN
# 10  Ann. Inst. H. Poincaré C Anal. Non Linéaire  2022      39    793--818
# 11                    Arch. Ration. Mech. Anal.  2021     241    683--727
# 12                            Stud. Appl. Math.  2020     144    289--326
# 13                         J. Math. Fluid Mech.  2018      20    445--472
# 14                                          NaN  2022    <NA>         NaN
# 15                                          NaN  2017    <NA>         NaN
# 16                                          NaN  2014    <NA>         NaN
#
#         eprint  url                                          eprinturl  \
# 0   2602.05981  NaN                                                NaN
# 1   2506.14533  NaN                                                NaN
# 2   2410.13127  NaN                                                NaN
# 3   2406.05043  NaN                                                NaN
# 4   2308.09350  NaN                                                NaN
# 5   2205.00362  NaN                                                NaN
# 6   2303.05236  NaN                                                NaN
# 7          NaN  NaN  https://optimization-online.org/wp-content/upl...
# 8   2110.02426  NaN                                                NaN
# 9          NaN  NaN  https://optimization-online.org/wp-content/upl...
# 10  2008.05588  NaN                                                NaN
# 11  2009.14291  NaN                                                NaN
# 12  1801.00950  NaN                                                NaN
# 13  1610.08924  NaN                                                NaN
# 14         NaN  NaN                                                NaN
# 15         NaN  NaN                                                NaN
# 16         NaN  NaN                                                NaN
#
#                                             publisher       address  \
# 0                                                 NaN           NaN
# 1                                                 NaN           NaN
# 2                                                 NaN           NaN
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# 5                                                 NaN           NaN
# 6                                   Taylor \& Francis           NaN
# 7                                                 NaN           NaN
# 8   Society for Industrial {\&} Applied Mathematic...           NaN
# 9                                                 NaN           NaN
# 10                                                NaN           NaN
# 11                                                NaN           NaN
# 12                                                NaN           NaN
# 13                                                NaN           NaN
# 14                                                NaN   Austin, USA
# 15                                                NaN  Xi'an, China
# 16                          Tsinghua University Press       Beijing
#
#                                                  link optonline
# 0                                                 NaN       NaN
# 1                                                 NaN       NaN
# 2                        https://www.iumj.indiana.edu       NaN
# 3                https://doi.org/10.3934/dcds.2025126       NaN
# 4                                                 NaN       NaN
# 5              https://doi.org/10.1287/opre.2023.0135       NaN
# 6       https://doi.org/10.1080/03605302.2024.2346146       NaN
# 7              https://doi.org/10.1287/mnsc.2023.4810     18579
# 8                  https://doi.org/10.1137/22m1503567       NaN
# 9                                                 NaN     20639
# 10                   https://doi.org/10.4171/aihpc/20       NaN
# 11         https://doi.org/10.1007/s00205-021-01661-4       NaN
# 12                 https://doi.org/10.1111/sapm.12297       NaN
# 13          https://doi.org/10.1007/s00021-017-0328-3       NaN
# 14                                                NaN       NaN
# 15                                                NaN       NaN
# 16  http://www.tup.tsinghua.edu.cn/booksCenter/boo...       NaN
